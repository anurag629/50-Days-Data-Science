# %% [markdown]
# # Write the output of following code snippits

# %%
x = 10
y = 5
z = x & y
print(z)

# %%
x = 10 
y = 5 
z = x | y 
print(z)

# %%
x = 10 
y = 5 
z = x ^ y 
print(z)

# %%
x = 10 
y = ~x 
print(y)

# %%
x = 10 
y = x << 2 
print(y)

# %%
x = 10 
y = x >> 2 
print(y)

# %%
x = 10 
y = 5 
z = x if x > y else y 
print(z)

# %%
x = "Hello"
y = x[0]
print(y)

# %%
x = "Hello"
y = x[1:3]
print(y)

# %%
x = 10
y = 5
z = x + y * 2
print(z)

# %%
x = 10
y = 5
z = x > y or x < y and x == 10
print(z)

# %%
x = 10 
y = 5
z = not x < y
print(z)

# %%
x = 10 
y = 5
z = (x * y) / (x - y)
print(z)
